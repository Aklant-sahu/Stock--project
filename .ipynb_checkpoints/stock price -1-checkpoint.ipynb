# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_ta

# %%
df1=pd.read_csv('Quote-Equity-TCS-EQ-15-12-2013-to-15-12-2015.csv')

# %% [markdown]
# ### ltp== last traded price
# ### vwap= volume weighted average price

# %%
df1
# Out:
#            Date  series      OPEN      HIGH       LOW  PREV. CLOSE       ltp   \
# 0    15-Dec-2015      EQ  2,378.45  2,385.00  2,363.05     2,378.45  2,379.50
# 1    14-Dec-2015      EQ  2,335.20  2,387.00  2,330.60     2,386.00  2,375.00
# 2    11-Dec-2015      EQ  2,383.00  2,391.95  2,363.25     2,384.55  2,383.15
# 3    10-Dec-2015      EQ  2,369.00  2,391.20  2,352.00     2,367.65  2,380.95
# 4    09-Dec-2015      EQ  2,337.90  2,372.80  2,320.00     2,329.00  2,370.00
# ..           ...     ...       ...       ...       ...          ...       ...
# 487  20-Dec-2013      EQ  2,088.10  2,130.00  2,085.85     2,081.50  2,128.15
# 488  19-Dec-2013      EQ  2,075.95  2,110.00  2,062.65     2,055.80  2,086.10
# 489  18-Dec-2013      EQ  2,040.00  2,071.00  2,038.00     2,045.35  2,055.50
# 490  17-Dec-2013      EQ  2,031.60  2,065.85  2,030.00     2,019.15  2,045.30
# 491  16-Dec-2013      EQ  2,013.70  2,039.80  2,005.15     2,001.80  2,020.20
#
# ...

# %%
df2=pd.read_csv('Quote-Equity-TCS-EQ-15-12-2015-to-14-12-2017.csv')

# %%
df3=pd.read_csv('Quote-Equity-TCS-EQ-15-12-2017-to-15-12-2019.csv')

# %%
df4=pd.read_csv('Quote-Equity-TCS-EQ-16-12-2019-to-15-12-2021.csv')

# %%
df1.sort_values(by='Date ')
# Out:
#            Date  series      OPEN      HIGH       LOW  PREV. CLOSE       ltp   \
# 417  01-Apr-2014      EQ  2,145.00  2,185.00  2,144.90     2,133.15  2,175.40
# 174  01-Apr-2015      EQ  2,558.00  2,563.60  2,522.25     2,553.95  2,544.05
# 335  01-Aug-2014      EQ  2,575.00  2,587.95  2,510.00     2,580.05  2,516.00
# 258  01-Dec-2014      EQ  2,650.50  2,700.00  2,645.25     2,643.00  2,691.90
# 10   01-Dec-2015      EQ  2,362.90  2,378.05  2,357.05     2,364.70  2,359.75
# ..           ...     ...       ...       ...       ...          ...       ...
# 336  31-Jul-2014      EQ  2,575.10  2,598.00  2,569.25     2,595.05  2,582.00
# 91   31-Jul-2015      EQ  2,489.90  2,519.00  2,487.00     2,480.65  2,511.45
# 418  31-Mar-2014      EQ  2,104.00  2,144.95  2,082.00     2,102.10  2,139.00
# 175  31-Mar-2015      EQ  2,569.45  2,569.45  2,521.00     2,564.15  2,560.00
# 277  31-Oct-2014      EQ  2,561.00  2,620.00  2,561.00     2,558.20  2,614.55
#
# ...

# %%
df1.columns
# Out:
# Index(['Date ', 'series ', 'OPEN ', 'HIGH ', 'LOW ', 'PREV. CLOSE ', 'ltp ',
#        'close ', 'vwap ', '52W H ', '52W L ', 'VOLUME ', 'VALUE ',
#        'No of trades '],
#       dtype='object')

# %%
df1['Date ']=pd.to_datetime(df1['Date '])

# %%
df1=df1.sort_values(by='Date ')

# %%
df2['Date ']=pd.to_datetime(df2['Date '])

df2=df2.sort_values(by='Date ')

# %%
df3['Date ']=pd.to_datetime(df3['Date '])

df3=df3.sort_values(by='Date ')

# %%
df4['Date ']=pd.to_datetime(df4['Date '])

df4=df4.sort_values(by='Date ')

# %%
df=pd.concat([df1,df2,df3,df4])

# %%
df
# Out:
#          Date  series      OPEN      HIGH       LOW  PREV. CLOSE       ltp   \
# 491 2013-12-16      EQ  2,013.70  2,039.80  2,005.15     2,001.80  2,020.20
# 490 2013-12-17      EQ  2,031.60  2,065.85  2,030.00     2,019.15  2,045.30
# 489 2013-12-18      EQ  2,040.00  2,071.00  2,038.00     2,045.35  2,055.50
# 488 2013-12-19      EQ  2,075.95  2,110.00  2,062.65     2,055.80  2,086.10
# 487 2013-12-20      EQ  2,088.10  2,130.00  2,085.85     2,081.50  2,128.15
# ..         ...     ...       ...       ...       ...          ...       ...
# 4   2021-12-09      EQ  3,610.00  3,634.75  3,566.00     3,626.90  3,600.00
# 3   2021-12-10      EQ  3,585.00  3,642.00  3,575.10     3,601.75  3,630.00
# 2   2021-12-13      EQ  3,650.00  3,662.00  3,601.70     3,636.80  3,615.00
# 1   2021-12-14      EQ  3,605.00  3,635.00  3,576.70     3,609.65  3,619.95
# 0   2021-12-15      EQ  3,620.00  3,623.00  3,558.15     3,623.80  3,571.00
#
# ...

# %%
df=df.reset_index()

# %%
df.columns
# Out:
# Index(['index', 'Date ', 'series ', 'OPEN ', 'HIGH ', 'LOW ', 'PREV. CLOSE ',
#        'ltp ', 'close ', 'vwap ', '52W H ', '52W L ', 'VOLUME ', 'VALUE ',
#        'No of trades '],
#       dtype='object')

# %%
df.drop('index',axis=1)
# Out:
#           Date  series      OPEN      HIGH       LOW  PREV. CLOSE       ltp   \
# 0    2013-12-16      EQ  2,013.70  2,039.80  2,005.15     2,001.80  2,020.20
# 1    2013-12-17      EQ  2,031.60  2,065.85  2,030.00     2,019.15  2,045.30
# 2    2013-12-18      EQ  2,040.00  2,071.00  2,038.00     2,045.35  2,055.50
# 3    2013-12-19      EQ  2,075.95  2,110.00  2,062.65     2,055.80  2,086.10
# 4    2013-12-20      EQ  2,088.10  2,130.00  2,085.85     2,081.50  2,128.15
# ...         ...     ...       ...       ...       ...          ...       ...
# 1973 2021-12-09      EQ  3,610.00  3,634.75  3,566.00     3,626.90  3,600.00
# 1974 2021-12-10      EQ  3,585.00  3,642.00  3,575.10     3,601.75  3,630.00
# 1975 2021-12-13      EQ  3,650.00  3,662.00  3,601.70     3,636.80  3,615.00
# 1976 2021-12-14      EQ  3,605.00  3,635.00  3,576.70     3,609.65  3,619.95
# 1977 2021-12-15      EQ  3,620.00  3,623.00  3,558.15     3,623.80  3,571.00
#
# ...

# %%
plt.plot(range(len(df['close '])),df['close '])

# %%
df.set_index(pd.DatetimeIndex(df['Date ']), inplace=True)

# %%
df.head()
# Out:
#             index      Date  series      OPEN      HIGH       LOW   \
# Date
# 2013-12-16    491 2013-12-16      EQ  2,013.70  2,039.80  2,005.15
# 2013-12-17    490 2013-12-17      EQ  2,031.60  2,065.85  2,030.00
# 2013-12-18    489 2013-12-18      EQ  2,040.00  2,071.00  2,038.00
# 2013-12-19    488 2013-12-19      EQ  2,075.95  2,110.00  2,062.65
# 2013-12-20    487 2013-12-20      EQ  2,088.10  2,130.00  2,085.85
#
#            PREV. CLOSE       ltp     close      vwap     52W H     52W L   \
# Date
# 2013-12-16     2,001.80  2,020.20  2,019.15  2,022.53  2,258.85  1,197.00
# 2013-12-17     2,019.15  2,045.30  2,045.35  2,051.44  2,258.85  1,197.00
# 2013-12-18     2,045.35  2,055.50  2,055.80  2,059.13  2,258.85  1,197.00
# 2013-12-19     2,055.80  2,086.10  2,081.50  2,086.33  2,258.85  1,197.00
# 2013-12-20     2,081.50  2,128.15  2,120.55  2,111.81  2,258.85  1,197.00
#
#             VOLUME             VALUE   No of trades
# Date
# ...

# %%
len(df)
# Out:
# 1978

# %%
df=df.drop(['index','Date ','series ','VALUE '],axis=1)

# %%
df.head()
# Out:
#                OPEN      HIGH       LOW  PREV. CLOSE       ltp     close   \
# Date
# 2013-12-16  2,013.70  2,039.80  2,005.15     2,001.80  2,020.20  2,019.15
# 2013-12-17  2,031.60  2,065.85  2,030.00     2,019.15  2,045.30  2,045.35
# 2013-12-18  2,040.00  2,071.00  2,038.00     2,045.35  2,055.50  2,055.80
# 2013-12-19  2,075.95  2,110.00  2,062.65     2,055.80  2,086.10  2,081.50
# 2013-12-20  2,088.10  2,130.00  2,085.85     2,081.50  2,128.15  2,120.55
#
#                vwap     52W H     52W L   VOLUME   No of trades
# Date
# 2013-12-16  2,022.53  2,258.85  1,197.00  1429250          70396
# 2013-12-17  2,051.44  2,258.85  1,197.00  1497737          67190
# 2013-12-18  2,059.13  2,258.85  1,197.00   793995          37832
# 2013-12-19  2,086.33  2,258.85  1,197.00  1080993          64976
# 2013-12-20  2,111.81  2,258.85  1,197.00   982906          52833

# %%
df.to_csv("merged")

# %%
sns.scatterplot(range(len(df['close '])),df['close '])

# %%
df.columns
# Out:
# Index(['OPEN ', 'HIGH ', 'LOW ', 'PREV. CLOSE ', 'ltp ', 'close ', 'vwap ',
#        '52W H ', '52W L ', 'VOLUME ', 'No of trades '],
#       dtype='object')

# %%
float(df['OPEN '][0].replace(',',''))
# Out:
# 2013.7

# %%
df.corr()
# Out:
#                 VOLUME   No of trades
# VOLUME         1.000000       0.806377
# No of trades   0.806377       1.000000

# %%
df.columns
# Out:
# Index(['OPEN ', 'HIGH ', 'LOW ', 'PREV. CLOSE ', 'ltp ', 'close ', 'vwap ',
#        '52W H ', '52W L ', 'VOLUME ', 'No of trades '],
#       dtype='object')

# %%
col=['OPEN ', 'HIGH ', 'LOW ', 'PREV. CLOSE ', 'ltp ', 'close ', 'vwap ',
       '52W H ', '52W L ']

# %%
print(col)
# Out:
# ['OPEN ', 'HIGH ', 'LOW ', 'PREV. CLOSE ', 'ltp ', 'close ', 'vwap ', '52W H ', '52W L ']

# %%
for i in col:
    for j in range(len(df)):
        
        try:
            x=float(df[i][j])
        except:
            x=float(df[i][j].replace(',',''))
        df[i][j]=x
# Out:
# c:\users\asus\anaconda3\envs\deep_lenv\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.dtypes
# Out:
# OPEN             object
# HIGH             object
# LOW              object
# PREV. CLOSE      object
# ltp              object
# close            object
# vwap             object
# 52W H            object
# 52W L            object
# VOLUME            int64
# No of trades      int64
# dtype: object

# %%
df=df.astype(float)

# %%
df.dtypes
# Out:
# OPEN             float64
# HIGH             float64
# LOW              float64
# PREV. CLOSE      float64
# ltp              float64
# close            float64
# vwap             float64
# 52W H            float64
# 52W L            float64
# VOLUME           float64
# No of trades     float64
# dtype: object

# %%
df.corr()['close ']
# Out:
# OPEN             0.996905
# HIGH             0.998814
# LOW              0.998690
# PREV. CLOSE      0.992122
# ltp              0.999933
# close            1.000000
# vwap             0.999525
# 52W H            0.416229
# 52W L            0.504248
# VOLUME          -0.070501
# No of trades    -0.009606
# Name: close , dtype: float64

# %%
df.ta.ema(close='close ', length=10, append=True)
# Out:
# Date
# 2013-12-16            NaN
# 2013-12-17            NaN
# 2013-12-18            NaN
# 2013-12-19            NaN
# 2013-12-20            NaN
#                  ...
# 2021-12-09    3573.423648
# 2021-12-10    3584.946621
# 2021-12-13    3589.438144
# 2021-12-14    3595.685754
# 2021-12-15    3591.079254
# Name: EMA_10, Length: 1978, dtype: float64

# %%
df
# Out:
#               OPEN     HIGH      LOW   PREV. CLOSE      ltp    close   \
# Date
# 2013-12-16  2013.70  2039.80  2005.15       2001.80  2020.20  2019.15
# 2013-12-17  2031.60  2065.85  2030.00       2019.15  2045.30  2045.35
# 2013-12-18  2040.00  2071.00  2038.00       2045.35  2055.50  2055.80
# 2013-12-19  2075.95  2110.00  2062.65       2055.80  2086.10  2081.50
# 2013-12-20  2088.10  2130.00  2085.85       2081.50  2128.15  2120.55
# ...             ...      ...      ...           ...      ...      ...
# 2021-12-09  3610.00  3634.75  3566.00       3626.90  3600.00  3601.75
# 2021-12-10  3585.00  3642.00  3575.10       3601.75  3630.00  3636.80
# 2021-12-13  3650.00  3662.00  3601.70       3636.80  3615.00  3609.65
# 2021-12-14  3605.00  3635.00  3576.70       3609.65  3619.95  3623.80
# 2021-12-15  3620.00  3623.00  3558.15       3623.80  3571.00  3570.35
#
#               vwap    52W H    52W L     VOLUME   No of trades        EMA_10
# Date
# ...

# %%
df=df[9:]

# %%
df
# Out:
#              OPEN     HIGH      LOW   PREV. CLOSE      ltp    close     vwap   \
# Date
# 2013-12-30  2170.0  2175.25  2146.70       2160.65  2159.00  2156.05  2159.98
# 2013-12-31  2160.1  2184.95  2150.90       2156.05  2174.25  2172.05  2171.87
# 2014-01-01  2180.1  2184.50  2151.10       2172.05  2153.70  2153.30  2159.55
# 2014-01-02  2166.0  2189.00  2156.15       2153.30  2167.95  2167.00  2170.96
# 2014-01-03  2164.7  2229.10  2147.25       2167.00  2224.10  2222.20  2206.70
# ...            ...      ...      ...           ...      ...      ...      ...
# 2021-12-09  3610.0  3634.75  3566.00       3626.90  3600.00  3601.75  3593.64
# 2021-12-10  3585.0  3642.00  3575.10       3601.75  3630.00  3636.80  3611.25
# 2021-12-13  3650.0  3662.00  3601.70       3636.80  3615.00  3609.65  3626.62
# 2021-12-14  3605.0  3635.00  3576.70       3609.65  3619.95  3623.80  3618.04
# 2021-12-15  3620.0  3623.00  3558.15       3623.80  3571.00  3570.35  3575.02
#
# ...

# %%
df.corr()['close ']
# Out:
# OPEN             0.996900
# HIGH             0.998810
# LOW              0.998688
# PREV. CLOSE      0.992100
# ltp              0.999933
# close            1.000000
# vwap             0.999524
# 52W H            0.413187
# 52W L            0.501701
# VOLUME          -0.072931
# No of trades    -0.012820
# EMA_10           0.984362
# Name: close , dtype: float64

# %%
df.ta.rsi(close='close ', length=10, append=True)
# Out:
# c:\users\asus\anaconda3\envs\deep_lenv\lib\site-packages\pandas_ta\core.py:426: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[ind_name] = result
# Date
# 2013-12-30          NaN
# 2013-12-31          NaN
# 2014-01-01          NaN
# 2014-01-02          NaN
# 2014-01-03          NaN
#                 ...
# 2021-12-09    57.520916
# 2021-12-10    61.702972
# 2021-12-13    56.883082
# 2021-12-14    58.749070
# 2021-12-15    49.718276
# Name: RSI_10, Length: 1969, dtype: float64

# %%
df
# Out:
#              OPEN     HIGH      LOW   PREV. CLOSE      ltp    close     vwap   \
# Date
# 2013-12-30  2170.0  2175.25  2146.70       2160.65  2159.00  2156.05  2159.98
# 2013-12-31  2160.1  2184.95  2150.90       2156.05  2174.25  2172.05  2171.87
# 2014-01-01  2180.1  2184.50  2151.10       2172.05  2153.70  2153.30  2159.55
# 2014-01-02  2166.0  2189.00  2156.15       2153.30  2167.95  2167.00  2170.96
# 2014-01-03  2164.7  2229.10  2147.25       2167.00  2224.10  2222.20  2206.70
# ...            ...      ...      ...           ...      ...      ...      ...
# 2021-12-09  3610.0  3634.75  3566.00       3626.90  3600.00  3601.75  3593.64
# 2021-12-10  3585.0  3642.00  3575.10       3601.75  3630.00  3636.80  3611.25
# 2021-12-13  3650.0  3662.00  3601.70       3636.80  3615.00  3609.65  3626.62
# 2021-12-14  3605.0  3635.00  3576.70       3609.65  3619.95  3623.80  3618.04
# 2021-12-15  3620.0  3623.00  3558.15       3623.80  3571.00  3570.35  3575.02
#
# ...

# %%
plt.plot(df['close '])
plt.plot(df['EMA_10'])

# %%
df=df[9:]

# %%
df=df[1:]

# %%
df
# Out:
#               OPEN     HIGH      LOW   PREV. CLOSE      ltp    close   \
# Date
# 2014-01-13  2285.00  2384.00  2285.00       2280.90  2380.00  2368.75
# 2014-01-14  2372.00  2384.80  2320.00       2368.75  2330.00  2326.75
# 2014-01-15  2342.45  2378.20  2327.00       2326.75  2361.00  2353.60
# 2014-01-16  2380.00  2380.10  2325.00       2353.60  2359.00  2350.30
# 2014-01-17  2298.00  2298.00  2206.05       2350.30  2219.85  2213.05
# ...             ...      ...      ...           ...      ...      ...
# 2021-12-09  3610.00  3634.75  3566.00       3626.90  3600.00  3601.75
# 2021-12-10  3585.00  3642.00  3575.10       3601.75  3630.00  3636.80
# 2021-12-13  3650.00  3662.00  3601.70       3636.80  3615.00  3609.65
# 2021-12-14  3605.00  3635.00  3576.70       3609.65  3619.95  3623.80
# 2021-12-15  3620.00  3623.00  3558.15       3623.80  3571.00  3570.35
#
#               vwap   52W H    52W L     VOLUME   No of trades        EMA_10  \
# Date
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop(['close '],axis=1)
y=df['close ']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.2,random_state=101)

# %%
from sklearn.linear_model import LinearRegression
# Create Regression Model
model = LinearRegression()
# Train the model
model.fit(X_train, y_train)
# Use model to make predictions
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
# Printout relevant metrics
print("Model Coefficients:", model.coef_)
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("Coefficient of Determination:", r2_score(y_test, y_pred))
# Out:
# Model Coefficients: [-3.93024424e-02 -1.16904024e-02 -1.33432502e-02 -7.70949989e-03
#   8.16295079e-01  2.46414450e-01  3.33135744e-05  1.28862621e-03
#   1.76262722e-07 -6.56853267e-06  8.03824558e-03  7.41784180e-02]
# Mean Absolute Error: 3.582576820849479
# Coefficient of Determination: 0.9998857096763405

# %%
res=pd.DataFrame(data=X_test)

# %%
res['target']=y_test

# %%
res['pred']=y_pred

# %%
act=[]
for i in range(0,len(res)):
    if (res['target'][i]>res['OPEN '][i]):
        act.append(1)
    else:
        act.append(0)

# %%
res['action']=act

# %%
res
# Out:
#               OPEN     HIGH      LOW   PREV. CLOSE      ltp     vwap   \
# Date
# 2014-09-23  2724.00  2782.45  2683.30       2721.80  2694.00  2721.78
# 2021-05-14  3098.50  3098.50  3040.00       3087.60  3052.00  3051.89
# 2015-07-29  2511.00  2515.05  2483.50       2502.05  2515.00  2501.68
# 2015-05-08  2560.00  2588.00  2516.30       2545.25  2530.00  2552.07
# 2014-07-10  2399.55  2419.60  2335.00       2398.15  2345.90  2375.22
# ...             ...      ...      ...           ...      ...      ...
# 2016-10-03  2450.00  2457.65  2401.10       2430.80  2407.50  2417.11
# 2021-04-26  3102.05  3153.00  3088.05       3109.50  3100.05  3122.35
# 2018-11-01  1943.65  1944.35  1901.30       1938.15  1928.00  1918.75
# 2019-05-22  2110.00  2121.95  2075.00       2109.75  2090.00  2091.31
# 2018-05-04  3492.00  3497.00  3470.00       3481.85  3479.00  3485.14
#
#              52W H    52W L     VOLUME   No of trades        EMA_10  \
# Date
# ...

# %%
sns.countplot(res['action'])

# %%
act=[]
for i in range(0,len(res)):
    if (res['pred'][i]>res['OPEN '][i]):
        act.append(1)
    else:
        act.append(0)

# %%
res['action_pred']=act

# %%
res.head()
# Out:
#               OPEN     HIGH     LOW   PREV. CLOSE     ltp     vwap    52W H   \
# Date
# 2014-09-23  2724.00  2782.45  2683.3       2721.80  2694.0  2721.78  2782.45
# 2021-05-14  3098.50  3098.50  3040.0       3087.60  3052.0  3051.89  3354.35
# 2015-07-29  2511.00  2515.05  2483.5       2502.05  2515.0  2501.68  2839.70
# 2015-05-08  2560.00  2588.00  2516.3       2545.25  2530.0  2552.07  2839.70
# 2014-07-10  2399.55  2419.60  2335.0       2398.15  2345.9  2375.22  2498.00
#
#             52W L     VOLUME   No of trades        EMA_10     RSI_10   target  \
# Date
# 2014-09-23  1916.7  1027995.0        60907.0  2643.540771  65.027656  2688.20
# 2021-05-14  1865.2  2043935.0       126572.0  3098.634434  38.573813  3051.50
# 2015-07-29  2345.0  1206659.0        85826.0  2518.829328  43.232953  2506.75
# 2015-05-08  1999.5  1501832.0        53709.0  2504.806862  52.292872  2527.25
# 2014-07-10  1495.3   995281.0        58688.0  2391.082717  50.167268  2351.80
#
# ...

# %%
sns.countplot(res['action_pred'])

# %%
mean_absolute_error(res['action'],res['action_pred'])
# Out:
# 0.05357142857142857

# %%
from sklearn.metrics import mean_squared_error,classification_report,accuracy_score

# %%
mean_squared_error(res['action'],res['action_pred'])
# Out:
# 0.05357142857142857

# %%
accuracy_score(res['action'],res['action_pred'])
# Out:
# 0.9464285714285714

# %%
print(classification_report(res['action'],res['action_pred']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       210
#            1       0.93      0.96      0.94       182
#
#     accuracy                           0.95       392
#    macro avg       0.95      0.95      0.95       392
# weighted avg       0.95      0.95      0.95       392

# %%
test=pd.read_csv('Quote-Equity-TCS-EQ-15-10-2021-to-15-01-2022.csv')

# %%
col
# Out:
# ['OPEN ',
#  'HIGH ',
#  'LOW ',
#  'PREV. CLOSE ',
#  'ltp ',
#  'close ',
#  'vwap ',
#  '52W H ',
#  '52W L ']

# %%
test.head()
# Out:
#          Date  series      OPEN      HIGH       LOW  PREV. CLOSE       ltp   \
# 0  14-Jan-2022      EQ  3,877.85  3,977.00  3,860.05     3,897.90  3,965.35
# 1  13-Jan-2022      EQ  3,918.00  3,923.00  3,857.00     3,859.90  3,898.00
# 2  12-Jan-2022      EQ  3,925.00  3,929.00  3,836.55     3,915.90  3,857.00
# 3  11-Jan-2022      EQ  3,856.00  3,925.00  3,856.00     3,879.85  3,917.00
# 4  10-Jan-2022      EQ  3,978.00  3,978.00  3,861.00     3,853.50  3,884.00
#
#      close      vwap     52W H     52W L   VOLUME              VALUE   \
# 0  3,968.15  3,924.25  3,989.90  2,880.00  3348123  13,138,881,273.10
# 1  3,897.90  3,891.72  3,989.90  2,880.00  6684507  26,014,258,279.50
# 2  3,859.90  3,874.16  3,989.90  2,880.00  3203744  12,411,815,990.80
# 3  3,915.90  3,896.96  3,989.90  2,880.00  1906106   7,428,014,700.35
# 4  3,879.85  3,897.84  3,989.90  2,880.00  3937092  15,346,166,149.80
#
#    No of trades
# 0         213960
# 1         401435
# 2         241232
# ...

# %%
test['Date ']=pd.to_datetime(test['Date '])

# %%
test=test.sort_values(by='Date ')

# %%
test.head()
# Out:
#         Date  series      OPEN      HIGH       LOW  PREV. CLOSE       ltp   \
# 62 2021-10-18      EQ  3,603.45  3,652.70  3,601.45     3,611.45  3,649.00
# 61 2021-10-19      EQ  3,669.00  3,690.10  3,625.20     3,647.15  3,634.45
# 60 2021-10-20      EQ  3,612.00  3,630.00  3,578.30     3,634.15  3,607.95
# 59 2021-10-21      EQ  3,604.10  3,607.45  3,511.25     3,608.85  3,532.85
# 58 2021-10-22      EQ  3,560.00  3,561.60  3,485.00     3,532.50  3,501.85
#
#       close      vwap     52W H     52W L   VOLUME              VALUE   \
# 62  3,647.15  3,631.23  3,989.90  2,600.05  3590107  13,036,517,799.15
# 61  3,634.15  3,661.85  3,989.90  2,600.05  3135441  11,481,500,581.85
# 60  3,608.85  3,606.05  3,989.90  2,600.05  2933693  10,579,039,337.05
# 59  3,532.50  3,546.27  3,989.90  2,600.05  4871211  17,274,650,004.55
# 58  3,498.85  3,511.44  3,989.90  2,600.05  2691670   9,451,650,099.45
#
#     No of trades
# 62         213590
# 61         191609
# 60         175675
# ...

# %%
test.set_index(pd.DatetimeIndex(test['Date ']), inplace=True)

# %%
test=test.drop(['Date ','series ','VALUE '],axis=1)

# %%
test.head()
# Out:
#                OPEN      HIGH       LOW  PREV. CLOSE       ltp     close   \
# Date
# 2021-10-18  3,603.45  3,652.70  3,601.45     3,611.45  3,649.00  3,647.15
# 2021-10-19  3,669.00  3,690.10  3,625.20     3,647.15  3,634.45  3,634.15
# 2021-10-20  3,612.00  3,630.00  3,578.30     3,634.15  3,607.95  3,608.85
# 2021-10-21  3,604.10  3,607.45  3,511.25     3,608.85  3,532.85  3,532.50
# 2021-10-22  3,560.00  3,561.60  3,485.00     3,532.50  3,501.85  3,498.85
#
#                vwap     52W H     52W L   VOLUME   No of trades
# Date
# 2021-10-18  3,631.23  3,989.90  2,600.05  3590107         213590
# 2021-10-19  3,661.85  3,989.90  2,600.05  3135441         191609
# 2021-10-20  3,606.05  3,989.90  2,600.05  2933693         175675
# 2021-10-21  3,546.27  3,989.90  2,600.05  4871211         295349
# 2021-10-22  3,511.44  3,989.90  2,600.05  2691670         163976

# %%
for i in col:
    for j in range(len(test)):
        
        try:
            x=float(test[i][j])
        except:
            x=float(test[i][j].replace(',',''))
        test[i][j]=x
# Out:
# c:\users\asus\anaconda3\envs\deep_lenv\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test.dtypes
# Out:
# OPEN             object
# HIGH             object
# LOW              object
# PREV. CLOSE      object
# ltp              object
# close            object
# vwap             object
# 52W H            object
# 52W L            object
# VOLUME            int64
# No of trades      int64
# dtype: object

# %%
test=test.astype(float)

# %%
test.ta.rsi(close='close ', length=10, append=True)
test.ta.ema(close='close ', length=10, append=True)
# Out:
# Date
# 2021-10-18            NaN
# 2021-10-19            NaN
# 2021-10-20            NaN
# 2021-10-21            NaN
# 2021-10-22            NaN
#                  ...
# 2022-01-10    3802.143533
# 2022-01-11    3822.826527
# 2022-01-12    3829.567159
# 2022-01-13    3841.991312
# 2022-01-14    3864.929255
# Name: EMA_10, Length: 63, dtype: float64

# %%
test
# Out:
#               OPEN     HIGH      LOW   PREV. CLOSE      ltp    close   \
# Date
# 2021-10-18  3603.45  3652.70  3601.45       3611.45  3649.00  3647.15
# 2021-10-19  3669.00  3690.10  3625.20       3647.15  3634.45  3634.15
# 2021-10-20  3612.00  3630.00  3578.30       3634.15  3607.95  3608.85
# 2021-10-21  3604.10  3607.45  3511.25       3608.85  3532.85  3532.50
# 2021-10-22  3560.00  3561.60  3485.00       3532.50  3501.85  3498.85
# ...             ...      ...      ...           ...      ...      ...
# 2022-01-10  3978.00  3978.00  3861.00       3853.50  3884.00  3879.85
# 2022-01-11  3856.00  3925.00  3856.00       3879.85  3917.00  3915.90
# 2022-01-12  3925.00  3929.00  3836.55       3915.90  3857.00  3859.90
# 2022-01-13  3918.00  3923.00  3857.00       3859.90  3898.00  3897.90
# 2022-01-14  3877.85  3977.00  3860.05       3897.90  3965.35  3968.15
#
#               vwap   52W H    52W L     VOLUME   No of trades      RSI_10  \
# Date
# ...

# %%
test=test[10:]

# %%
test
# Out:
#               OPEN     HIGH      LOW   PREV. CLOSE      ltp    close   \
# Date
# 2021-11-01  3437.95  3487.00  3412.95       3397.75  3482.35  3476.40
# 2021-11-02  3494.00  3513.60  3469.75       3476.40  3484.00  3484.20
# 2021-11-03  3504.20  3519.90  3466.05       3484.20  3488.00  3492.25
# 2021-11-04  3512.95  3513.25  3505.00       3492.25  3508.65  3508.65
# 2021-11-08  3548.00  3548.00  3481.20       3508.65  3506.00  3502.75
# 2021-11-09  3508.00  3535.00  3496.00       3502.75  3503.00  3505.70
# 2021-11-10  3498.00  3519.70  3480.20       3505.70  3484.95  3484.30
# 2021-11-11  3480.00  3510.05  3436.00       3484.30  3505.00  3488.20
# 2021-11-12  3506.00  3534.15  3485.70       3488.20  3524.00  3526.05
# 2021-11-15  3528.00  3569.60  3528.00       3526.05  3550.00  3553.30
# 2021-11-16  3569.00  3575.55  3542.00       3553.30  3548.00  3556.40
# 2021-11-17  3550.60  3562.85  3506.40       3556.40  3520.80  3521.90
# ...

# %%
test_pred = model.predict(test.drop(['close '],axis=1))

# %%
test_pred
# Out:
# array([3704.69134456, 3713.2220286 , 3716.2153416 , 3736.5504899 ,
#        3731.03599576, 3731.68807449, 3713.62423435, 3724.2137206 ,
#        3749.33656175, 3780.11532059, 3778.66345952, 3750.86983082,
#        3699.57127954, 3695.09642179, 3696.73248137, 3665.4396157 ,
#        3676.97721633, 3668.79644827, 3729.24567405, 3763.59769006,
#        3807.33694342, 3862.92581211, 3871.40716595, 3770.92483348,
#        3818.59318041, 3858.49494986, 3829.98909446, 3860.87182345,
#        3849.26336102, 3854.19523031, 3802.85699852, 3818.23046249,
#        3814.48422431, 3793.53124046, 3847.45065219, 3861.71576275,
#        3894.92507691, 3906.21085206, 3931.33262394, 3945.26280269,
#        3929.17866919, 3975.686645  , 3980.0065453 , 4057.27237116,
#        4119.1480602 , 4097.61379422, 4052.76975118, 4102.17452243,
#        4129.37419535, 4163.13900854, 4105.87555425, 4144.68772012,
#        4210.68474729])

# %%
ans=pd.DataFrame(data=test)

# %%
ans
# Out:
#               OPEN     HIGH      LOW   PREV. CLOSE      ltp    close   \
# Date
# 2021-11-01  3437.95  3487.00  3412.95       3397.75  3482.35  3476.40
# 2021-11-02  3494.00  3513.60  3469.75       3476.40  3484.00  3484.20
# 2021-11-03  3504.20  3519.90  3466.05       3484.20  3488.00  3492.25
# 2021-11-04  3512.95  3513.25  3505.00       3492.25  3508.65  3508.65
# 2021-11-08  3548.00  3548.00  3481.20       3508.65  3506.00  3502.75
# 2021-11-09  3508.00  3535.00  3496.00       3502.75  3503.00  3505.70
# 2021-11-10  3498.00  3519.70  3480.20       3505.70  3484.95  3484.30
# 2021-11-11  3480.00  3510.05  3436.00       3484.30  3505.00  3488.20
# 2021-11-12  3506.00  3534.15  3485.70       3488.20  3524.00  3526.05
# 2021-11-15  3528.00  3569.60  3528.00       3526.05  3550.00  3553.30
# 2021-11-16  3569.00  3575.55  3542.00       3553.30  3548.00  3556.40
# 2021-11-17  3550.60  3562.85  3506.40       3556.40  3520.80  3521.90
# ...

# %%
ans['pred']=test_pred

# %%
ans
# Out:
#               OPEN     HIGH      LOW   PREV. CLOSE      ltp    close   \
# Date
# 2021-11-01  3437.95  3487.00  3412.95       3397.75  3482.35  3476.40
# 2021-11-02  3494.00  3513.60  3469.75       3476.40  3484.00  3484.20
# 2021-11-03  3504.20  3519.90  3466.05       3484.20  3488.00  3492.25
# 2021-11-04  3512.95  3513.25  3505.00       3492.25  3508.65  3508.65
# 2021-11-08  3548.00  3548.00  3481.20       3508.65  3506.00  3502.75
# 2021-11-09  3508.00  3535.00  3496.00       3502.75  3503.00  3505.70
# 2021-11-10  3498.00  3519.70  3480.20       3505.70  3484.95  3484.30
# 2021-11-11  3480.00  3510.05  3436.00       3484.30  3505.00  3488.20
# 2021-11-12  3506.00  3534.15  3485.70       3488.20  3524.00  3526.05
# 2021-11-15  3528.00  3569.60  3528.00       3526.05  3550.00  3553.30
# 2021-11-16  3569.00  3575.55  3542.00       3553.30  3548.00  3556.40
# 2021-11-17  3550.60  3562.85  3506.40       3556.40  3520.80  3521.90
# ...

# %%
act=[]
for i in range(0,len(ans)):
    if (ans['close '][i]>ans['OPEN '][i]):
        act.append(1)
    else:
        act.append(0)

ans['action']=act

# %%
ans
# Out:
#               OPEN     HIGH      LOW   PREV. CLOSE      ltp    close   \
# Date
# 2021-11-01  3437.95  3487.00  3412.95       3397.75  3482.35  3476.40
# 2021-11-02  3494.00  3513.60  3469.75       3476.40  3484.00  3484.20
# 2021-11-03  3504.20  3519.90  3466.05       3484.20  3488.00  3492.25
# 2021-11-04  3512.95  3513.25  3505.00       3492.25  3508.65  3508.65
# 2021-11-08  3548.00  3548.00  3481.20       3508.65  3506.00  3502.75
# 2021-11-09  3508.00  3535.00  3496.00       3502.75  3503.00  3505.70
# 2021-11-10  3498.00  3519.70  3480.20       3505.70  3484.95  3484.30
# 2021-11-11  3480.00  3510.05  3436.00       3484.30  3505.00  3488.20
# 2021-11-12  3506.00  3534.15  3485.70       3488.20  3524.00  3526.05
# 2021-11-15  3528.00  3569.60  3528.00       3526.05  3550.00  3553.30
# 2021-11-16  3569.00  3575.55  3542.00       3553.30  3548.00  3556.40
# 2021-11-17  3550.60  3562.85  3506.40       3556.40  3520.80  3521.90
# ...

# %%
act=[]
for i in range(0,len(ans)):
    if (ans['pred'][i]>ans['OPEN '][i]):
        act.append(1)
    else:
        act.append(0)

ans['action_pred']=act

# %%
ans
# Out:
#               OPEN     HIGH      LOW   PREV. CLOSE      ltp    close   \
# Date
# 2021-11-01  3437.95  3487.00  3412.95       3397.75  3482.35  3476.40
# 2021-11-02  3494.00  3513.60  3469.75       3476.40  3484.00  3484.20
# 2021-11-03  3504.20  3519.90  3466.05       3484.20  3488.00  3492.25
# 2021-11-04  3512.95  3513.25  3505.00       3492.25  3508.65  3508.65
# 2021-11-08  3548.00  3548.00  3481.20       3508.65  3506.00  3502.75
# 2021-11-09  3508.00  3535.00  3496.00       3502.75  3503.00  3505.70
# 2021-11-10  3498.00  3519.70  3480.20       3505.70  3484.95  3484.30
# 2021-11-11  3480.00  3510.05  3436.00       3484.30  3505.00  3488.20
# 2021-11-12  3506.00  3534.15  3485.70       3488.20  3524.00  3526.05
# 2021-11-15  3528.00  3569.60  3528.00       3526.05  3550.00  3553.30
# 2021-11-16  3569.00  3575.55  3542.00       3553.30  3548.00  3556.40
# 2021-11-17  3550.60  3562.85  3506.40       3556.40  3520.80  3521.90
# ...

# %% [markdown]
# # New approach

# %%
df
# Out:
#               OPEN     HIGH      LOW   PREV. CLOSE      ltp    close   \
# Date
# 2014-01-13  2285.00  2384.00  2285.00       2280.90  2380.00  2368.75
# 2014-01-14  2372.00  2384.80  2320.00       2368.75  2330.00  2326.75
# 2014-01-15  2342.45  2378.20  2327.00       2326.75  2361.00  2353.60
# 2014-01-16  2380.00  2380.10  2325.00       2353.60  2359.00  2350.30
# 2014-01-17  2298.00  2298.00  2206.05       2350.30  2219.85  2213.05
# ...             ...      ...      ...           ...      ...      ...
# 2021-12-09  3610.00  3634.75  3566.00       3626.90  3600.00  3601.75
# 2021-12-10  3585.00  3642.00  3575.10       3601.75  3630.00  3636.80
# 2021-12-13  3650.00  3662.00  3601.70       3636.80  3615.00  3609.65
# 2021-12-14  3605.00  3635.00  3576.70       3609.65  3619.95  3623.80
# 2021-12-15  3620.00  3623.00  3558.15       3623.80  3571.00  3570.35
#
#               vwap   52W H    52W L     VOLUME   No of trades        EMA_10  \
# Date
# ...

# %%
col
# Out:
# ['OPEN ',
#  'HIGH ',
#  'LOW ',
#  'PREV. CLOSE ',
#  'ltp ',
#  'close ',
#  'vwap ',
#  '52W H ',
#  '52W L ']

# %%
def clean(data):
    col=['OPEN ','HIGH ','LOW ','PREV. CLOSE ','ltp ','close ','vwap ','52W H ','52W L ']
    data['Date ']=pd.to_datetime(data['Date '])
    data=data.sort_values(by='Date ')
    data.set_index(pd.DatetimeIndex(data['Date ']), inplace=True)
    try:
        data=data.drop(['Date ','series ','VALUE '],axis=1)
    except:
        data=data.drop(['Date '],axis=1)
    for i in col:
        for j in range(len(data)):

            try:
                x=float(data[i][j])
            except:
                x=float(data[i][j].replace(',',''))
            data[i][j]=x
    data=data.astype(float)
    
    return data

# %%
def emarsi(data):
    data.ta.rsi(close='close ', length=10, append=True)
    data.ta.ema(close='close ', length=10, append=True)
    data=data[10:]
    return data

# %%
def datashift(data):
    
    col=['OPEN ','HIGH ','LOW ','ltp ','vwap ','VOLUME ','No of trades ','RSI_10','EMA_10']
    ### ltp== last traded price
    ### vwap= volume weighted average price
    data=data.reset_index(drop=True)
    for j in col:
        x=[]
        for i in range(len(data)):
            if (i==0):
                x.append(0)
            else:
                x.append(data[j][i-1])
        nam='prev_'+j
        data[nam]=x
    
    
    data=data.drop(col,axis=1)
    data=data[1:]
    data=data.reset_index(drop=True)
    #data=data.drop(['PREV. CLOSE '],axis=1)
    return data

# %%
def xy(data):
    X=data.drop('close ',axis=1)
    y=data['close ']
    return X,y

# %%
a=clean(test)
b=emarsi(a)
c=datashift(b)
# Out:
# c:\users\asus\anaconda3\envs\deep_lenv\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
c.head()
# Out:
#    PREV. CLOSE    close   52W H    52W L   prev_OPEN   prev_HIGH   prev_LOW   \
# 0       3476.40  3484.20  3989.9  2600.05     3437.95     3487.00    3412.95
# 1       3484.20  3492.25  3989.9  2600.05     3494.00     3513.60    3469.75
# 2       3492.25  3508.65  3989.9  2600.05     3504.20     3519.90    3466.05
# 3       3508.65  3502.75  3989.9  2607.05     3512.95     3513.25    3505.00
# 4       3502.75  3505.70  3989.9  2607.05     3548.00     3548.00    3481.20
#
#    prev_ltp   prev_vwap   prev_VOLUME   prev_No of trades   prev_RSI_10  \
# 0    3482.35     3445.74     2020718.0            154841.0    34.778012
# 1    3484.00     3490.81     3087414.0            134659.0    37.040826
# 2    3488.00     3492.58     1537639.0             98779.0    39.449785
# 3    3508.65     3509.12      328991.0             42244.0    44.276116
# 4    3506.00     3503.30     2526082.0            144893.0    42.908969
#
#    prev_EMA_10
# 0  3512.580000
# 1  3507.420000
# 2  3504.661818
# ...

# %%
df=pd.read_csv('merged')
df.head()
# Out:
#         Date      OPEN      HIGH       LOW  PREV. CLOSE       ltp     close   \
# 0  2013-12-16  2,013.70  2,039.80  2,005.15     2,001.80  2,020.20  2,019.15
# 1  2013-12-17  2,031.60  2,065.85  2,030.00     2,019.15  2,045.30  2,045.35
# 2  2013-12-18  2,040.00  2,071.00  2,038.00     2,045.35  2,055.50  2,055.80
# 3  2013-12-19  2,075.95  2,110.00  2,062.65     2,055.80  2,086.10  2,081.50
# 4  2013-12-20  2,088.10  2,130.00  2,085.85     2,081.50  2,128.15  2,120.55
#
#       vwap     52W H     52W L   VOLUME   No of trades
# 0  2,022.53  2,258.85  1,197.00  1429250          70396
# 1  2,051.44  2,258.85  1,197.00  1497737          67190
# 2  2,059.13  2,258.85  1,197.00   793995          37832
# 3  2,086.33  2,258.85  1,197.00  1080993          64976
# 4  2,111.81  2,258.85  1,197.00   982906          52833

# %%
a=clean(df)
b=emarsi(a)
c=datashift(b)
# Out:
# c:\users\asus\anaconda3\envs\deep_lenv\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
X,y=xy(c)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale=StandardScaler()

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.2,random_state=101)

# %%
X_train=scale.fit_transform(X_train)
X_test=scale.transform(X_test)

# %%
from sklearn.svm import SVR

# %%
from sklearn.linear_model import LinearRegression

# Create Regression Model
mod2=SVR()
model = LinearRegression()
# Train the model
model.fit(X_train, y_train)
mod2.fit(X_train, y_train)
# Use model to make predictions
y_pred = model.predict(X_test)
y_pred2 = mod2.predict(X_test)

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
# Printout relevant metrics
print("Model Coefficients:", model.coef_)
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("Coefficient of Determination:", r2_score(y_test, y_pred))
print("Mean Absolute Error  2:", mean_absolute_error(y_test, y_pred2))
# Out:
# Model Coefficients: [  -3.91218718    0.59337406    2.9711129   -62.37456375  155.36317366
#   142.06136741  435.24276308 -227.61422981    0.68789077    0.55465131
#     0.96034751   -5.18418828]
# Mean Absolute Error: 26.74777980689854
# Coefficient of Determination: 0.9927119339609646
# Mean Absolute Error  2: 200.00375199677447

# %%
c.corr()['close ']
# Out:
# PREV. CLOSE           0.992096
# close                 1.000000
# 52W H                 0.412676
# 52W L                 0.501410
# prev_OPEN             0.989114
# prev_HIGH             0.990919
# prev_LOW              0.990939
# prev_ltp              0.992162
# prev_vwap             0.991585
# prev_VOLUME          -0.071796
# prev_No of trades    -0.013183
# prev_RSI_10           0.284303
# prev_EMA_10           0.976478
# Name: close , dtype: float64

# %%
c.columns
# Out:
# Index(['PREV. CLOSE ', 'close ', '52W H ', '52W L ', 'prev_OPEN ',
#        'prev_HIGH ', 'prev_LOW ', 'prev_ltp ', 'prev_vwap ', 'prev_VOLUME ',
#        'prev_No of trades ', 'prev_RSI_10', 'prev_EMA_10'],
#       dtype='object')

# %%
y_test
# Out:
# 1319    2152.85
# 1052    2950.30
# 1342    2252.80
# 770     2406.25
# 1117    1883.00
#          ...
# 1629    2295.35
# 1131    1943.75
# 1192    1894.80
# 532     2210.50
# 619     2429.80
# Name: close , Length: 394, dtype: float64

# %%
def buysell(Xg,yg,pred):
    data=pd.DataFrame(Xg)
    data['current_close']=yg
    data['pred']=pred
    data.reset_index(inplace=True)
    act=[]
    
    for i in range(len(data)):
        
        if (float(data['current_close'][i]) > data['PREV. CLOSE '][i]):
            act.append(1)
        else:
            act.append(0)

    data['action']=act
    act=[]
    for i in range(len(data)):
        if (data['pred'][i]>data['PREV. CLOSE '][i]):
            act.append(1)
        else:
            act.append(0)

    data['action_pred']=act
    return data

# %%
ans=buysell(X_test,y_test,y_pred)

# %%
accuracy_score(ans['action'],ans['action_pred'])
# Out:
# 0.47715736040609136

# %%
print(classification_report(ans['action'],ans['action_pred']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.44      0.60       345
#            1       0.15      0.71      0.25        49
#
#     accuracy                           0.48       394
#    macro avg       0.54      0.58      0.43       394
# weighted avg       0.82      0.48      0.55       394

# %%
test=pd.read_csv('Quote-Equity-TCS-EQ-15-10-2021-to-15-01-2022.csv')

# %%
a=clean(test)
b=emarsi(a)
c=datashift(b)

X,y=xy(c)
y_pred = model.predict(scale.transform(X))
# Out:
# c:\users\asus\anaconda3\envs\deep_lenv\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ans=buysell(X,y,y_pred)

# %%
accuracy_score(ans['action'],ans['action_pred'])
# Out:
# 0.4807692307692308

# %%
print(classification_report(ans['action'],ans['action_pred']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.37      0.94      0.53        16
#            1       0.91      0.28      0.43        36
#
#     accuracy                           0.48        52
#    macro avg       0.64      0.61      0.48        52
# weighted avg       0.74      0.48      0.46        52

# %% [markdown]
# ## try with percentage for linear regression output and logistic model
